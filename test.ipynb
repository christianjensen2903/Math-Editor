# %%
import latex2sympy2
import sympy

# %%
def latex_to_sympy(latex: str) -> str:
    """Convert latex to sympy"""

    # If the latex contains an equal sign subtract the left side from the right side
    if latex.find('=') != -1: 
        latex = latex.replace('=', '-(') + ')'

    return latex2sympy2.latex2sympy(latex)

# %%
latex_to_sympy(r"5").doit()+10
# Out:
# 15

# %%
# lamdify with 2 variables
sympy.lambdify(sympy.symbols('x,y'), sympy.sympify('x**2 + 2*x+y + 1'))(2, 3)

# %%
sympy.plotting.plot(sympy.sympify('x**2 + 2*x+y + 1'))

# %%
sympy.symbols('x,y')
# Out:
# (x, y)

# %%
x, y = sympy.symbols('x y')
sympy.solve(x**2 - y, x)
# Out:
# [-sqrt(y), sqrt(y)]

# %%
x = 5
sympy.solve(x**2 - y, y)
# Out:
# [25]

# %%
y = sympy.Symbol('y')
x = sympy.Symbol('x')
expr = sympy.solve(latex2sympy2.latex2sympy(r'5x-y').doit(),y)[0]
sympy.lambdify(x, expr)(2)
# Out:
# 10

# %%
variables = {
    'x': sympy.Symbol('x'),
    'y': sympy.Symbol('y')
}

sympy.utilities.lambdify(variables.values, expr)(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/s3/51rzg94s5318dvd1cr9t6cq40000gn/T/ipykernel_46197/4179160621.py in <module>
#       4 }
#       5
# ----> 6 sympy.utilities.lambdify(variables.values, expr)(2)
#
# /opt/homebrew/lib/python3.9/site-packages/sympy/utilities/lambdify.py in lambdify(args, expr, modules, printer, use_imps, dummify, cse)
#     834     # Grab the callers frame, for getting the names by inspection (if needed)
#     835     callers_local_vars = inspect.currentframe().f_back.f_locals.items() # type: ignore
# --> 836     for n, var in enumerate(iterable_args):
#     837         if hasattr(var, 'name'):
#     838             names.append(var.name)
#
# TypeError: 'builtin_function_or_method' object is not iterable

# %%
x = sympy.Symbol('x')
sympy.lambdify(x, x**2)(2)
# Out:
# 4

# %%
import re

match = re.compile(r"^solve\((.*?)(,(.*))?\)$").match("solve(x**2 - 4, x)")

len(match.groups())
# Out:
# 3

# %%
regex = re.compile(r"^(?P<variable>\w+) = (?P<expression>.+)$")
match = regex.match("x = 5")
match.group('variable')
# Out:
# 'x'

# %%
latex2sympy2.latex2sympy(r'5x').doit()
# Out:
# 5*x
